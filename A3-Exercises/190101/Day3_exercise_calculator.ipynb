# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..\..\..'))
	print(os.getcwd())
except:
	pass

# %%
print('欢迎使用糖果简易计算器')         # 界面提示
print('-------------------')
while True:
    a = input('请输入等式（退出计算器请输入y）:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
    else:
        print("输入错误")
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器
# -------------------
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-5-181392b757e6> in <module>
#       2 print('-------------------')
#       3 while True:
# ----> 4     a = input('请输入等式（退出计算器请输入y）:')
#       5
#       6     if a == 'y' :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
def add(x,y)
    return x+y
def substact(x,y)
    return x-y
def multiply(x,y):
    return x*y
def divide(x,y):
    return x/y
print("Select operation")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")
choice=input("Enter choice(1/2/3/4):")
choice=input("Enter choice(1/2/3/4):")
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
if choice=='1':
    print(num1,"+",num2,"=",add(num1,num2))
elif choice=='2':
    print(num1,"-",num2,"=",subtract(num1,num2))
elif choice=='3':
    print(num1,"*",num2,"=",multiply(num1,num2))
elif choice=='4':
    print(num1,"/",num2,"=",divide(num1,num2))
else:
    print("Invalid input")
# Out:
#   File "<ipython-input-6-e5537bc2bb31>", line 1
#     def add(x,y)
#                 ^
# SyntaxError: invalid syntax

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000000000537E5F8>>

# %%
print('欢迎使用糖果简易计算器')         # 界面提示
print('-------------------')
while True:
    a = input('请输入等式（退出计算器请输入y）:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
    else:
        print("输入错误")
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器
# -------------------
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-8-181392b757e6> in <module>
#       2 print('-------------------')
#       3 while True:
# ----> 4     a = input('请输入等式（退出计算器请输入y）:')
#       5
#       6     if a == 'y' :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
print('欢迎使用糖果简易计算器')         # 界面提示
print('-------------------')
while True:
    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
    else:
        print("输入错误")
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器
# -------------------
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-9-ada9ae467e3e> in <module>
#       2 print('-------------------')
#       3 while True:
# ----> 4     a = input('请输入等式【退出计算器请输入y】:')
#       5
#       6     if a == 'y' :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
print('欢迎使用糖果简易计算器')         # 界面提示
print('-------------------')
while True:
    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器
# -------------------
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-10-abfa34265e7d> in <module>
#       2 print('-------------------')
#       3 while True:
# ----> 4     a = input('请输入等式【退出计算器请输入y】:')
#       5
#       6     if a == 'y' :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
        break
# Out:
#   File "<ipython-input-11-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %%
print('欢迎使用糖果简易计算器')         # 界面提示
print('-------------------')
while True :
    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器
# -------------------
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-12-a46032d8b5e1> in <module>
#       2 print('-------------------')
#       3 while True :
# ----> 4     a = input('请输入等式【退出计算器请输入y】:')
#       5
#       6     if a == 'y' :
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
while True :
    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
# 欢迎使用糖果简易计算器1.0
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-13-635d8711f436> in <module>
#       7 print("4.Divide")
#       8
# ----> 9 choice = input("Enter choice(1/2/3/4):")
#      10
#      11 a = int(input("Enter first number:"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-14-659da7e80387>", line 32
#     a = input('请输入等式【退出计算器请输入y】:')
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == 'y' :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-15-c16c825d2fee>", line 34
#     if a == 'y' :
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == y :
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-16-246b18c0fccf>", line 34
#     if a == y :
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == y:
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-17-2da1c189f312>", line 34
#     if a == y:
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
    if a == y
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-18-87ba4f788b08>", line 34
#     if a == y
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
        print("谢谢使用!")
        break
    elif a:
        print(a)
        continue
    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<tokenize>", line 37
#     elif a:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
        print("谢谢使用!")
        break
#    elif a:
        print(a)
        continue
#    else:
        print("输入错误")
        continue
        
print('-------------------')
# Out:
#   File "<ipython-input-21-b8d71c19b9ed>", line 35
#     print("谢谢使用!")
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
        print("谢谢使用!")
        break
#    elif a:
        print(a)
        continue
#    else:
        print("输入错误")
        continue
        
#print('-------------------')
# Out:
#   File "<ipython-input-22-1193497f2a92>", line 35
#     print("谢谢使用!")
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
        print("Invalid input")
        break
#    elif a:
        print(a)
        continue
#    else:
        print("输入错误")
        continue
        
#print('-------------------')
# Out:
#   File "<ipython-input-23-d81468c9f7d7>", line 35
#     print("Invalid input")
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
#        print("谢谢使用!")
        break
#    elif a:
        print(a)
        continue
#    else:
        print("输入错误")
        continue
        
#print('-------------------')
# Out:
#   File "<ipython-input-24-a4e89acde8c8>", line 36
#     break
#     ^
# IndentationError: unexpected indent

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")





print('欢迎使用糖果简易计算器2.0')         # 界面提示
print('-------------------')
# while True :
#    a = input('请输入等式【退出计算器请输入y】:')
    
#    if a == y
#        print("谢谢使用!")
#        break
#    elif a:
#        print(a)
#        continue
#    else:
#        print("输入错误")
#        continue
        
#print('-------------------')
# Out:
# 欢迎使用糖果简易计算器1.0
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-25-d3c480b909b7> in <module>
#       7 print("4.Divide")
#       8
# ----> 9 choice = input("Enter choice(1/2/3/4):")
#      10
#      11 a = int(input("Enter first number:"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
print("4.Divide")
# Out:
# 4.Divide

# %%
print('欢迎使用糖果简易计算器1.0')         # 界面提示

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = input("Enter choice(1/2/3/4):")

a = int(input("Enter first number:"))
b = int(input("Enter second number:"))

if choice == '1':
    print(a, "+", b, "=", a+b)
elif choice == '2':
    print(a, "-", b, "=", a-b)
elif choice == '3':
    print(a, "*", b, "=", a*b)
elif choice == '4':
    print(a, "/", b, "=", a/b)
else:
    print("Invalid input")
# Out:
# 欢迎使用糖果简易计算器1.0
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-27-97be1d28a5c5> in <module>
#       7 print("4.Divide")
#       8
# ----> 9 choice = input("Enter choice(1/2/3/4):")
#      10
#      11 a = int(input("Enter first number:"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846         if not self._allow_stdin:
#     847             raise StdinNotImplementedError(
# --> 848                 "raw_input was called, but this frontend does not support input requests."
#     849             )
#     850         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.
